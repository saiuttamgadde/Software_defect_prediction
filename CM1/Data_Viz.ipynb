# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data1 = pd.read_csv('cm1.csv')
data1.head()
# Out:
#    McCabe's line count of code  McCabe "cyclomatic complexity”  \
# 0                          1.1                             1.4
# 1                          1.0                             1.0
# 2                         24.0                             5.0
# 3                         20.0                             4.0
# 4                         24.0                             6.0
#
#    McCabe "essential complexity”  McCabe "design complexity”  \
# 0                            1.4                         1.4
# 1                            1.0                         1.0
# 2                            1.0                         3.0
# 3                            4.0                         2.0
# 4                            6.0                         2.0
#
#    Halstead total operators + operands  Halstead "volume”  \
# 0                                  1.3               1.30
# 1                                  1.0               1.00
# 2                                 63.0             309.13
# 3                                 47.0             215.49
# 4                                 72.0             346.13
#
#    Halstead "program length”  Halstead "difficulty”  Halstead "intelligence”  \
# 0                       1.30                   1.30                     1.30
# 1                       1.00                   1.00                     1.00
# 2                       0.11                   9.50                    32.54
# 3                       0.06                  16.00                    13.47
# 4                       0.06                  17.33                    19.97
#
#    Halstead "effort”  ...  Halstead's line count  \
# 0               1.30  ...                      2
# 1               1.00  ...                      1
# 2            2936.77  ...                      1
# 3            3447.89  ...                      0
# 4            5999.58  ...                      0
#
#    Halstead's count of lines of comments  Halstead's count of blank  \
# 0                                      2                          2
# 1                                      1                          1
# 2                                      0                          6
# 3                                      0                          3
# 4                                      0                          3
#
#    lineslOCodeAndComment  unique operators  unique operands  total operators  \
# 0                      2               1.2              1.2              1.2
# 1                      1               1.0              1.0              1.0
# 2                      0              15.0             15.0             44.0
# 3                      0              16.0              8.0             31.0
# 4                      0              16.0             12.0             46.0
#
#    total operands  branchCount of the flow graph  defects
# 0             1.2                            1.4    False
# 1             1.0                            1.0     True
# 2            19.0                            9.0    False
# 3            16.0                            7.0    False
# 4            26.0                           11.0    False
#
# [5 rows x 22 columns]

# %%
data1.shape
# Out:
# (498, 22)

# %%
data1.isnull().sum()
# Out:
# McCabe's line count of code              0
# McCabe "cyclomatic complexity”           0
# McCabe "essential complexity”            0
# McCabe "design complexity”               0
# Halstead total operators + operands      0
# Halstead "volume”                        0
# Halstead "program length”                0
# Halstead "difficulty”                    0
# Halstead "intelligence”                  0
# Halstead "effort”                        0
# Halstead                                 0
# Halstead's time estimator                0
# Halstead's line count                    0
# Halstead's count of lines of comments    0
# Halstead's count of blank                0
# lineslOCodeAndComment                    0
# unique operators                         0
# unique operands                          0
# total operators                          0
# total operands                           0
# branchCount of the flow graph            0
# defects                                  0
# dtype: int64

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 498 entries, 0 to 497
# Data columns (total 22 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   McCabe's line count of code            498 non-null    float64
#  1   McCabe "cyclomatic complexity”         498 non-null    float64
#  2   McCabe "essential complexity”          498 non-null    float64
#  3   McCabe "design complexity”             498 non-null    float64
#  4   Halstead total operators + operands    498 non-null    float64
#  5   Halstead "volume”                      498 non-null    float64
#  6   Halstead "program length”              498 non-null    float64
#  7   Halstead "difficulty”                  498 non-null    float64
#  8   Halstead "intelligence”                498 non-null    float64
#  9   Halstead "effort”                      498 non-null    float64
#  10  Halstead                               498 non-null    float64
#  11  Halstead's time estimator              498 non-null    float64
#  12  Halstead's line count                  498 non-null    int64
#  13  Halstead's count of lines of comments  498 non-null    int64
#  14  Halstead's count of blank              498 non-null    int64
#  15  lineslOCodeAndComment                  498 non-null    int64
#  16  unique operators                       498 non-null    float64
#  17  unique operands                        498 non-null    float64
#  18  total operators                        498 non-null    float64
#  19  total operands                         498 non-null    float64
#  20  branchCount of the flow graph          498 non-null    float64
#  21  defects                                498 non-null    bool
# dtypes: bool(1), float64(17), int64(4)
# memory usage: 82.3 KB

# %%
correlation=data1.corr()

plt.figure(figsize=(20,10))
sns.heatmap(correlation,annot=True)
# Out:
# <AxesSubplot:>

# %%
data1.describe()
# Out:
#        McCabe's line count of code  McCabe "cyclomatic complexity”  \
# count                   498.000000                      498.000000
# mean                     29.644779                        5.382329
# std                      42.753572                        8.347359
# min                       1.000000                        1.000000
# 25%                       8.000000                        1.000000
# 50%                      17.000000                        3.000000
# 75%                      31.000000                        6.000000
# max                     423.000000                       96.000000
#
#        McCabe "essential complexity”  McCabe "design complexity”  \
# count                     498.000000                  498.000000
# mean                        2.490763                    3.528916
# std                         3.658847                    5.464398
# min                         1.000000                    1.000000
# 25%                         1.000000                    1.000000
# 50%                         1.000000                    2.000000
# 75%                         1.000000                    4.000000
# max                        30.000000                   63.000000
#
#        Halstead total operators + operands  Halstead "volume”  \
# count                           498.000000         498.000000
# mean                            143.956426         900.175823
# std                             221.049888        1690.814334
# min                               1.000000           0.000000
# 25%                              25.000000         102.190000
# 50%                              67.500000         329.820000
# 75%                             151.750000         861.460000
# max                            2075.000000       17124.280000
#
#        Halstead "program length”  Halstead "difficulty”  \
# count                 498.000000             498.000000
# mean                    0.146325              15.829378
# std                     0.159337              15.330960
# min                     0.000000               0.000000
# 25%                     0.050000               5.630000
# 50%                     0.090000              11.640000
# 75%                     0.177500              21.142500
# max                     1.300000             125.770000
#
#        Halstead "intelligence”  Halstead "effort”  ...  \
# count               498.000000       4.980000e+02  ...
# mean                 38.455361       3.488493e+04  ...
# std                  36.996297       1.341647e+05  ...
# min                   0.000000       0.000000e+00  ...
# 25%                  16.210000       6.061700e+02  ...
# 50%                  27.400000       3.677620e+03  ...
# 75%                  46.900000       1.663334e+04  ...
# max                 293.680000       2.153691e+06  ...
#
#        Halstead's time estimator  Halstead's line count  \
# count                 498.000000             498.000000
# mean                 1938.056124               3.787149
# std                  7453.591519               8.508658
# min                     0.000000               0.000000
# 25%                    33.672500               0.000000
# 50%                   204.310000               1.000000
# 75%                   924.075000               4.000000
# max                119649.480000              80.000000
#
#        Halstead's count of lines of comments  Halstead's count of blank  \
# count                             498.000000                 498.000000
# mean                               12.283133                  11.534137
# std                                25.828605                  19.981476
# min                                 0.000000                   0.000000
# 25%                                 0.000000                   1.000000
# 50%                                 4.000000                   5.000000
# 75%                                14.000000                  13.000000
# max                               339.000000                 164.000000
#
#        lineslOCodeAndComment  unique operators  unique operands  \
# count             498.000000        498.000000       498.000000
# mean                0.006024         15.199197        25.452209
# std                 0.100120          9.617815        33.925816
# min                 0.000000          1.000000         0.000000
# 25%                 0.000000          9.000000         7.000000
# 50%                 0.000000         14.000000        15.000000
# 75%                 0.000000         20.000000        30.000000
# max                 2.000000         72.000000       314.000000
#
#        total operators  total operands  branchCount of the flow graph
# count       498.000000      498.000000                     498.000000
# mean         88.389960       55.570683                       9.348193
# std         134.917513       86.969527                      15.072219
# min           1.000000        0.000000                       1.000000
# 25%          15.000000       10.000000                       1.000000
# 50%          42.000000       26.000000                       5.000000
# 75%          94.750000       59.750000                      11.000000
# max        1261.000000      814.000000                     162.000000
#
# [8 rows x 21 columns]

# %%
data1.groupby('defects').size()
# Out:
# defects
# False    449
# True      49
# dtype: int64

# %%
sns.countplot(x='defects',data=data1)
sns.set_theme(style='whitegrid')
plt.figure(figsize=(12,10))

# %%
data1.head()
# Out:
#    McCabe's line count of code  McCabe "cyclomatic complexity”  \
# 0                          1.1                             1.4
# 1                          1.0                             1.0
# 2                         24.0                             5.0
# 3                         20.0                             4.0
# 4                         24.0                             6.0
#
#    McCabe "essential complexity”  McCabe "design complexity”  \
# 0                            1.4                         1.4
# 1                            1.0                         1.0
# 2                            1.0                         3.0
# 3                            4.0                         2.0
# 4                            6.0                         2.0
#
#    Halstead total operators + operands  Halstead "volume”  \
# 0                                  1.3               1.30
# 1                                  1.0               1.00
# 2                                 63.0             309.13
# 3                                 47.0             215.49
# 4                                 72.0             346.13
#
#    Halstead "program length”  Halstead "difficulty”  Halstead "intelligence”  \
# 0                       1.30                   1.30                     1.30
# 1                       1.00                   1.00                     1.00
# 2                       0.11                   9.50                    32.54
# 3                       0.06                  16.00                    13.47
# 4                       0.06                  17.33                    19.97
#
#    Halstead "effort”  ...  Halstead's line count  \
# 0               1.30  ...                      2
# 1               1.00  ...                      1
# 2            2936.77  ...                      1
# 3            3447.89  ...                      0
# 4            5999.58  ...                      0
#
#    Halstead's count of lines of comments  Halstead's count of blank  \
# 0                                      2                          2
# 1                                      1                          1
# 2                                      0                          6
# 3                                      0                          3
# 4                                      0                          3
#
#    lineslOCodeAndComment  unique operators  unique operands  total operators  \
# 0                      2               1.2              1.2              1.2
# 1                      1               1.0              1.0              1.0
# 2                      0              15.0             15.0             44.0
# 3                      0              16.0              8.0             31.0
# 4                      0              16.0             12.0             46.0
#
#    total operands  branchCount of the flow graph  defects
# 0             1.2                            1.4    False
# 1             1.0                            1.0     True
# 2            19.0                            9.0    False
# 3            16.0                            7.0    False
# 4            26.0                           11.0    False
#
# [5 rows x 22 columns]

# %%
data1.defects = data1['defects']*1

# %%
data1.head()
# Out:
#    McCabe's line count of code  McCabe "cyclomatic complexity”  \
# 0                          1.1                             1.4
# 1                          1.0                             1.0
# 2                         24.0                             5.0
# 3                         20.0                             4.0
# 4                         24.0                             6.0
#
#    McCabe "essential complexity”  McCabe "design complexity”  \
# 0                            1.4                         1.4
# 1                            1.0                         1.0
# 2                            1.0                         3.0
# 3                            4.0                         2.0
# 4                            6.0                         2.0
#
#    Halstead total operators + operands  Halstead "volume”  \
# 0                                  1.3               1.30
# 1                                  1.0               1.00
# 2                                 63.0             309.13
# 3                                 47.0             215.49
# 4                                 72.0             346.13
#
#    Halstead "program length”  Halstead "difficulty”  Halstead "intelligence”  \
# 0                       1.30                   1.30                     1.30
# 1                       1.00                   1.00                     1.00
# 2                       0.11                   9.50                    32.54
# 3                       0.06                  16.00                    13.47
# 4                       0.06                  17.33                    19.97
#
#    Halstead "effort”  ...  Halstead's line count  \
# 0               1.30  ...                      2
# 1               1.00  ...                      1
# 2            2936.77  ...                      1
# 3            3447.89  ...                      0
# 4            5999.58  ...                      0
#
#    Halstead's count of lines of comments  Halstead's count of blank  \
# 0                                      2                          2
# 1                                      1                          1
# 2                                      0                          6
# 3                                      0                          3
# 4                                      0                          3
#
#    lineslOCodeAndComment  unique operators  unique operands  total operators  \
# 0                      2               1.2              1.2              1.2
# 1                      1               1.0              1.0              1.0
# 2                      0              15.0             15.0             44.0
# 3                      0              16.0              8.0             31.0
# 4                      0              16.0             12.0             46.0
#
#    total operands  branchCount of the flow graph  defects
# 0             1.2                            1.4        0
# 1             1.0                            1.0        1
# 2            19.0                            9.0        0
# 3            16.0                            7.0        0
# 4            26.0                           11.0        0
#
# [5 rows x 22 columns]

# %%
X= data1.iloc[:,:-1]
y= data1.iloc[:,-1]

# %%
# !pip install imblearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: imblearn in c:\users\sai utham\appdata\roaming\python\python38\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\sai utham\appdata\roaming\python\python38\site-packages (from imblearn) (0.8.0)
# Requirement already satisfied: scipy>=0.19.1 in c:\program files\anaconda\lib\site-packages (from imbalanced-learn->imblearn) (1.5.2)
# Requirement already satisfied: scikit-learn>=0.24 in c:\users\sai utham\appdata\roaming\python\python38\site-packages (from imbalanced-learn->imblearn) (0.24.2)
# Requirement already satisfied: joblib>=0.11 in c:\program files\anaconda\lib\site-packages (from imbalanced-learn->imblearn) (0.17.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\program files\anaconda\lib\site-packages (from imbalanced-learn->imblearn) (1.19.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\program files\anaconda\lib\site-packages (from scikit-learn>=0.24->imbalanced-learn->imblearn) (2.1.0)

# %%
from imblearn.over_sampling import SMOTE

# %%
y_sm.value_counts()
# Out:
# 0    449
# 1     49
# Name: defects, dtype: int64
